# %% [markdown]
# # Goal

# %% [markdown]
# Using historical returns between Jun 1 2019 and Nov 10 2022 find the optimal investment portfolio.

# %% [markdown]
# The companies considered - Ekspress Grupp, HansaMatrix, Tallinna Sadam, Tallina Vesi.

# %% [markdown]
# ### Ekspress Grupp (EG)

# %% [markdown]
# Estonian media group. 5 media companies belong to Ekspress Grupp (EG), websites, various digital media channels.

# %% [markdown]
# ### HansaMatrix (HM)

# %% [markdown]
# HansaMatrix is one of the leading manufacturers of electronic systems and components in Northern Europe for transportation, telecommunications, energy management systems, IoT, medicine and defence technology sectors.

# %% [markdown]
# ### Tallinna Sadam (TS)

# %% [markdown]
# One of the biggest port complexes in the Baltic sea. Owner of 4 ports - 2 of which are passenger oriented, the other 2 meant for cargo.

# %% [markdown]
# ### Tallinna Vesi (TV)

# %% [markdown]
# Tallinna Vesi is the largest water utility in Estonia, providing drinking water and wastewater services to nearly one third of Estonian population.

# %% [markdown]
# # Stock prices during the period of interest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Historical day returns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Expected yearly returns rates

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Covariation matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Markowitz method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We are looking for the biggest return for the smallest possible variation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# R is the chosen yearly return rate.

# %% [markdown]
# # Markowitz frontier

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Without solving an optimization problem

# %% [markdown]
# ![outlier_bullet.PNG](attachment:outlier_bullet.PNG)

# %% [markdown]
# # The optimal portfolios for various rates of return.

# %% [markdown]
# ![image.png](attachment:image.png)
